# %% [markdown]
# <a href="https://colab.research.google.com/github/Megh-Zyke/Basic_MLprojects/blob/main/linear/estimation_of_car_price(linear_regression).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Estimation of carprice using linear regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("//content//CarPrice_Assignment (1).csv")

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df["symboling"].value_counts()
# Out:
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: symboling, dtype: int64

# %%
print(df.isnull().sum())
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
print(df.shape," " ,len(df.columns) )
# Out:
# (205, 26)   26

# %% [markdown]
# Visualization of Data

# %%
def scatter_plot(x):

    plt.scatter(df[x],df["price"]);
    plt.title(x + ' vs price')
    plt.ylabel("price")
    plt.xlabel(x)
    plt.show()

scatter_plot("fueltype")
scatter_plot("carbody")
scatter_plot("drivewheel")
scatter_plot("horsepower")
scatter_plot("CarName")

# %%
plt1 = sns.countplot("CarName" , data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
fig, axes = plt.subplots(2,3, sharex=True ,figsize = (20,10))
sns.distplot(ax=axes[0,0] , x=df.carlength )
sns.boxplot(df.carlength,ax=axes[0,1])
sns.lineplot(x = df.carlength,y = df.price ,ax=axes[0,2])

sns.distplot(ax=axes[1,0] , x=df.horsepower )
sns.boxplot(df.horsepower,ax=axes[1,1])
sns.lineplot(x = df.horsepower,y = df.price ,ax=axes[1,2])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# ...

# %%
fig, axes = plt.subplots(1,3, sharex=True ,figsize = (20,5))
sns.distplot(ax=axes[0] , x=df.peakrpm )
sns.boxplot(df.peakrpm,ax=axes[1])
sns.lineplot(x = df.peakrpm,y = df.price ,ax=axes[2])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
fig, axes = plt.subplots(1,3, sharex=True ,figsize = (20,5))
sns.distplot(ax=axes[0] , x=df.carbody )
sns.boxplot(df.carbody,ax=axes[1])
sns.lineplot(x = df.carbody,y = df.price ,ax=axes[2])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Manipulating the data

# %%
print(df.describe())
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
print(df["fueltype"].value_counts())

df["fueltype"] = df["fueltype"].replace({"gas":0,"diesel":1})
# Out:
# gas       185
# diesel     20
# Name: fueltype, dtype: int64

# %%
print(df["aspiration"].value_counts())

df["aspiration"] = df["aspiration"].replace({"std":0,"turbo":1})
# Out:
# std      168
# turbo     37
# Name: aspiration, dtype: int64

# %%
print(df["doornumber"].value_counts())

df["doornumber"] = df["doornumber"].replace({"two":0,"four":1})
# Out:
# four    115
# two      90
# Name: doornumber, dtype: int64

# %%
print(df["carbody"].value_counts())

df["carbody"] = df["carbody"].replace({"sedan":0,"hatchback":1,"wagon":2,"hardtop":3,"convertible":4})
# Out:
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: carbody, dtype: int64

# %%
print(df["drivewheel"].value_counts())
df["drivewheel"] = df["drivewheel"].replace({"fwd":0,"rwd":1,"4wd":2})
# Out:
# fwd    120
# rwd     76
# 4wd      9
# Name: drivewheel, dtype: int64

# %%
print(df["enginelocation"].value_counts())
df["enginelocation"] = df["enginelocation"].replace({"front":0,"rear":3})
# Out:
# front    202
# rear       3
# Name: enginelocation, dtype: int64

# %%
print(df["enginetype"].value_counts())
df["enginetype"] = df["enginetype"].replace({"ohc":0,"ohcf":1,"ohcv":2,"dohc":3,"l":4,"rotor":5,"dohcv":6})
# Out:
# ohc      148
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# dohcv      1
# Name: enginetype, dtype: int64

# %%
print(df["cylindernumber"].value_counts())
df["cylindernumber"] = df["cylindernumber"].replace({"four":4,"six":6,"five":5,"eight":8,"two":2,"three":3,"twelve":12})
# Out:
# four      159
# six        24
# five       11
# eight       5
# two         4
# three       1
# twelve      1
# Name: cylindernumber, dtype: int64

# %%
print(df["fuelsystem"].value_counts())
df["fuelsystem"]  = df["fuelsystem"].replace({"mpfi":0,"2bbl":1,"idi":2,"1bbl":3,"spdi":4,"4bbl":5,"mfi":6,"spfi":7})
# Out:
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# mfi      1
# spfi     1
# Name: fuelsystem, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    int64
#  4   aspiration        205 non-null    int64
#  5   doornumber        205 non-null    int64
#  6   carbody           205 non-null    int64
#  7   drivewheel        205 non-null    int64
#  8   enginelocation    205 non-null    int64
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    int64
#  15  cylindernumber    205 non-null    int64
# ...

# %% [markdown]
# Getting the data ready for ml

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName  fueltype  aspiration  \
# 0       1          3        alfa-romero giulia         0           0
# 1       2          3       alfa-romero stelvio         0           0
# 2       3          1  alfa-romero Quadrifoglio         0           0
# 3       4          2               audi 100 ls         0           0
# 4       5          2                audi 100ls         0           0
#
#    doornumber  carbody  drivewheel  enginelocation  wheelbase  ...  \
# 0           0        4           1               0       88.6  ...
# 1           0        4           1               0       88.6  ...
# 2           0        1           1               0       94.5  ...
# 3           1        0           0               0       99.8  ...
# 4           1        0           2               0       99.4  ...
#
#    enginesize  fuelsystem  boreratio  stroke  compressionratio  horsepower  \
# ...

# %%
x = df.drop(columns=["car_ID","CarName","price"])
y = df.price

# %%
print(x.shape , y.shape)
# Out:
# (205, 23) (205,)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state = 3)

# %%
from sklearn.linear_model import LinearRegression as l_reg

# %%
model = l_reg()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
X = model.predict(x_test)

# %%
from sklearn.metrics import r2_score
acc = r2_score(y_test,X)
print(acc)
print("The accuracy of the testing data is ",acc)


x2 = model.predict(x_train)
acc2 = r2_score(y_train,x2)
print("The accuracy of the training data is ",acc2)
# Out:
# 0.8687595826372827
# The accuracy of the testing data is  0.8687595826372827
# The accuracy of the training data is  0.8806798134377811

# %%
fig, (ax1,ax2)= plt.subplots(1,2,figsize = (15,10))

ax1.scatter(y_train,x2,c = "g")
ax1.plot(y_train,y_train, c = "b")
ax1.set_title('Linear Regression for training data')
ax1.set(xlabel='Orginal Data', ylabel='Predicted Data')

ax2.scatter(y_test,X,c = "r")
ax2.plot(y_test,y_test, c = "y")
ax2.set_title('Linear Regression for training data')
ax2.set(xlabel='Orginal Data', ylabel='Predicted Data')
# Out:
# [Text(0, 0.5, 'Predicted Data'), Text(0.5, 0, 'Orginal Data')]
