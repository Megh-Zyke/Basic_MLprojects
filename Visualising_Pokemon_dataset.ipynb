# %% [markdown]
# <a href="https://colab.research.google.com/github/Megh-Zyke/Basic_MLprojects/blob/main/Visualising_Pokemon_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# importing the dataset

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d0e61398-6f69-4d10-9a3c-42870a0ccb85" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d0e61398-6f69-4d10-9a3c-42870a0ccb85">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving pokemon.csv to pokemon.csv

# %%
# declaring object df to contain the dataset pokemon.csv
df = pd.read_csv("pokemon.csv")

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
table = df.drop(columns = "#")

# %%
table.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison    318  45      49       49       65
# 1                Ivysaur  Grass  Poison    405  60      62       63       80
# 2               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
print("The revised information on pokemon.csv dataset is \n")
print(table.info())
print("The columns in this dataset are :",table.columns)
# Out:
# The revised information on pokemon.csv dataset is
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        800 non-null    object
#  1   Type 1      800 non-null    object
#  2   Type 2      414 non-null    object
#  3   Total       800 non-null    int64
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB
# None
# The columns in this dataset are : Index(['Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
# ...

# %%
table.describe()
# Out:
#            Total          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.00000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   435.10250   69.258750   79.001250   73.842500   72.820000   71.902500
# std    119.96304   25.534669   32.457366   31.183501   32.722294   27.828916
# min    180.00000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    330.00000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    450.00000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    515.00000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    780.00000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
# renaming columns
table = table.rename(columns = {"Type 1":"Type1","Type 2":"Type2"})

# %%
# getting some specific values
Grass_poison = table.query('Type1=="Grass" & Type2=="Poison"')
Grass_poison
# this table contains all the obejcts with type 1 as grass anf type 2 as poison
# Out:
#                       Name  Type1   Type2  Total   HP  Attack  Defense  \
# 0                Bulbasaur  Grass  Poison    318   45      49       49
# 1                  Ivysaur  Grass  Poison    405   60      62       63
# 2                 Venusaur  Grass  Poison    525   80      82       83
# 3    VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 48                  Oddish  Grass  Poison    320   45      50       55
# 49                   Gloom  Grass  Poison    395   60      65       70
# 50               Vileplume  Grass  Poison    490   75      80       85
# 75              Bellsprout  Grass  Poison    300   50      75       35
# 76              Weepinbell  Grass  Poison    390   65      90       50
# 77              Victreebel  Grass  Poison    490   80     105       65
# 344                Roselia  Grass  Poison    400   50      60       45
# 451                  Budew  Grass  Poison    280   40      30       35
# ...

# %%
fire_flying_legend = table[(table.Type1=="Fire")&(table.Type2=="Flying")&(table.Legendary== True)]
fire_flying_legend
# this table contains the pokemon with type 1 as fire type 2 as flying and are legendary
# Out:
#         Name Type1   Type2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 158  Moltres  Fire  Flying    580   90     100       90      125       85
# 270    Ho-oh  Fire  Flying    680  106     130       90      110      154
#
#      Speed  Generation  Legendary
# 158     90           1       True
# 270     90           2       True

# %% [markdown]
# Visualising The data

# %%
# Visualising the the gen 1 pokemon
table.Generation.value_counts()
# Out:
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: Generation, dtype: int64

# %%
gen1 = table.query('Generation==1')
gen1
#we have created a table for gen 1 pokemon
# Out:
#                       Name    Type1     Type2  Total   HP  Attack  Defense  \
# 0                Bulbasaur    Grass    Poison    318   45      49       49
# 1                  Ivysaur    Grass    Poison    405   60      62       63
# 2                 Venusaur    Grass    Poison    525   80      82       83
# 3    VenusaurMega Venusaur    Grass    Poison    625   80     100      123
# 4               Charmander     Fire       NaN    309   39      52       43
# ..                     ...      ...       ...    ...  ...     ...      ...
# 161              Dragonite   Dragon    Flying    600   91     134       95
# 162                 Mewtwo  Psychic       NaN    680  106     110       90
# 163    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190      100
# 164    MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150       70
# 165                    Mew  Psychic       NaN    600  100     100      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
plt.figure(figsize=(10,9))
p = sns.swarmplot(x =table.Name,y =table.Total,hue=table.Legendary)
plt.show()

# %%
# some countplots and comparison
fig , axs = plt.subplots(2,3,figsize =(25,8))
sns.countplot(gen1.Legendary ,ax=axs[0,0])
sns.countplot(gen1.Type1,ax=axs[0,1])
sns.countplot(gen1.Type2,ax=axs[0,2])
sns.countplot(table.Generation ,  hue=table.Legendary,ax=axs[1,0])
sns.countplot(table.Type1 , hue=table.Legendary ,ax=axs[1,1])
sns.countplot(table.Type2 , hue=table.Legendary  ,ax=axs[1,2])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
# plotting the type 1 pokemon with respect to Type 2
plt.figure(figsize=(22,12))
sns.countplot(table.Type1,hue = table.Type2 )
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# acquiring the pokemon with highest stats in gen1
max(gen1.Total)
gen1.query('Total==780')
# Out:
#                     Name    Type1     Type2  Total   HP  Attack  Defense  \
# 163  MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190      100
# 164  MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150       70
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 163      154      100    130           1       True
# 164      194      120    140           1       True

# %%
# acquiring the pokemon with highest stats all over
max(table.Total)
table.query('Total == 780')
# Out:
#                       Name    Type1     Type2  Total   HP  Attack  Defense  \
# 163    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190      100
# 164    MewtwoMega Mewtwo Y  Psychic      None    780  106     150       70
# 426  RayquazaMega Rayquaza   Dragon    Flying    780  105     180      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 163      154      100    130           1          1
# 164      194      120    140           1          1
# 426      180      100    115           3          1

# %%
# getting the highest stats in each gen
gen2 = table.query('Generation == 2')
gen3 = table.query('Generation == 3')
gen4 = table.query('Generation == 4')
gen5 = table.query('Generation == 5')
gen6 = table.query('Generation == 6')
#created tables specific to each generation

# %%
gen1_max_stats = max(gen1.Total)
gen2_max_stats = max(gen2.Total)
gen3_max_stats = max(gen3.Total)
gen4_max_stats = max(gen4.Total)
gen5_max_stats = max(gen5.Total)
gen6_max_stats = max(gen6.Total)
print(gen1_max_stats,gen2_max_stats,gen3_max_stats,gen4_max_stats,gen5_max_stats,gen6_max_stats)
# Out:
# 780 700 780 720 700 700

# %%
t1=gen1.query('Total == 780 ')
t2=gen2.query('Total == 700 ')
t3=gen3.query('Total == 780 ')
t4=gen4.query('Total == 720 ')
t5=gen5.query('Total == 700 ')
t6=gen6.query('Total == 700 ')

# %%
x = [t1,t2,t3,t4,t5,t6]
for i in range(0,6):
  print(x[i].Name)
# Out:
# 163    MewtwoMega Mewtwo X
# 164    MewtwoMega Mewtwo Y
# Name: Name, dtype: object
# 268    TyranitarMega Tyranitar
# Name: Name, dtype: object
# 426    RayquazaMega Rayquaza
# Name: Name, dtype: object
# 552    Arceus
# Name: Name, dtype: object
# 711    KyuremBlack Kyurem
# 712    KyuremWhite Kyurem
# Name: Name, dtype: object
# 796    DiancieMega Diancie
# Name: Name, dtype: object

# %%
highest_stats = table.query('Name == ["MewtwoMega Mewtwo X","MewtwoMega Mewtwo Y","TyranitarMega Tyranitar","RayquazaMega Rayquaza","Arceus","KyuremBlack Kyurem","KyuremWhite Kyurem","DiancieMega Diancie"]')
highest_stats
# Out:
#                         Name    Type1     Type2  Total   HP  Attack  Defense  \
# 163      MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190      100
# 164      MewtwoMega Mewtwo Y  Psychic      None    780  106     150       70
# 268  TyranitarMega Tyranitar     Rock      Dark    700  100     164      150
# 426    RayquazaMega Rayquaza   Dragon    Flying    780  105     180      100
# 552                   Arceus   Normal      None    720  120     120      120
# 711       KyuremBlack Kyurem   Dragon       Ice    700  125     170      100
# 712       KyuremWhite Kyurem   Dragon       Ice    700  125     120       90
# 796      DiancieMega Diancie     Rock     Fairy    700   50     160      110
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 163      154      100    130           1          1
# 164      194      120    140           1          1
# 268       95      120     71           2          0
# 426      180      100    115           3          1
# ...

# %%
# using concat to form a table
max_stats = pd.DataFrame(columns = df.columns)
max_stats = pd.concat([t1,t2,t3,t4,t5,t6])
max_stats
# Out:
#                         Name    Type1     Type2  Total   HP  Attack  Defense  \
# 163      MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190      100
# 164      MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150       70
# 268  TyranitarMega Tyranitar     Rock      Dark    700  100     164      150
# 426    RayquazaMega Rayquaza   Dragon    Flying    780  105     180      100
# 552                   Arceus   Normal      None    720  120     120      120
# 711       KyuremBlack Kyurem   Dragon       Ice    700  125     170      100
# 712       KyuremWhite Kyurem   Dragon       Ice    700  125     120       90
# 796      DiancieMega Diancie     Rock     Fairy    700   50     160      110
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 163      154      100    130           1          1
# 164      194      120    140           1          1
# 268       95      120     71           2          0
# 426      180      100    115           3          1
# ...

# %%
# replacing the Values in a column
table.Type2 = table.Type2.replace(np.nan,"None")
z= table
z.Legendary = z.Legendary.replace({True:1,False:0})

# %%
#renaming a column
z = z.rename(columns = {'Legendary': 'legendary'})
z
# Out:
#                       Name    Type1   Type2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass  Poison    318  45      49       49
# 1                  Ivysaur    Grass  Poison    405  60      62       63
# 2                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire    None    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  legendary
# ...

# %%
# merging columns
table_m = pd.merge(table,z)
table_m.tail()
# Out:
#                     Name    Type1  Type2  Total  HP  Attack  Defense  Sp. Atk  \
# 795              Diancie     Rock  Fairy    600  50     100      150      100
# 796  DiancieMega Diancie     Rock  Fairy    700  50     160      110      160
# 797  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60      150
# 798   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60      170
# 799            Volcanion     Fire  Water    600  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary  legendary
# 795      150     50           6          1          1
# 796      110    110           6          1          1
# 797      130     70           6          1          1
# 798      130     80           6          1          1
# 799       90     70           6          1          1

# %%
fig , axis = plt.subplots(1,2,figsize=(20,10))
axis[0].set_title("Variation of Attack of Pokemon")
axis[0].set_xlabel("Pokemon")
axis[0].set_ylabel("Attack")

axis[1].set_title("Variation of Total of Pokemon")
axis[1].set_xlabel("Pokemon")
axis[1].set_ylabel("Total")

axis[0].plot(table.Name,table.Attack,color='c')
sns.lineplot(table.Name,table.Total,color = 'y' ,ax=axis[1])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
