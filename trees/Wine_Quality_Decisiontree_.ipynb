# %% [markdown]
# <a href="https://colab.research.google.com/github/Megh-Zyke/Basic_MLprojects/blob/main/trees/Wine_Quality_Decisiontree_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DETERMING THE WINE QUALITY USING DECSION TREE

# %%
#importing the necessary lilbraries for handeling datasets and visualising them
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing the dataset to google colab workspace
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a5a1b3d0-07f3-46f1-931f-39e44b13df2a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a5a1b3d0-07f3-46f1-931f-39e44b13df2a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving WineQT.csv to WineQT.csv

# %%
# assigning a object to contain the data set WineQT
df = pd.read_csv("WineQT.csv")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
# getting the basic information on the dataset
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB
# None

# %%
# Our dependent variables is the column quality and the inpdepemdent ones are the features
# check for null values
df.isnull().sum()
# there are no null values
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
# the id column is unnecessary for us and that is being removed
table = df.drop(columns = "Id")

# %% [markdown]
# Visualising the Data set

# %%
sns.countplot(df.quality)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#creating a column vector containing the index of the column name of the dataset
col = table.columns
col
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
def plot(x):
  sns.scatterplot(df[x],df.quality)
  plt.title(x + ' vs quality of wine')
  plt.show()
  sns.distplot(df[x])
  plt.title("Distrinution of " + x)
  plt.show()
# defining a function to get the scatterplots of the features with respect to quality

# %%
for i in range(0,len(col)-1):
  plot(col[i])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %%
table.quality.value_counts()
table.quality = table.quality.replace({3:5,4:5,7:8})

table.quality.value_counts()
# Out:
# 5    522
# 6    462
# 8    159
# Name: quality, dtype: int64

# %%
def clean_out(i):
  q1 = df[i].quantile(0.25)
  q2 = df[i].quantile(0.50)
  q3 = df[i].quantile(0.75)
  inter = q3 -q1
  u = q3 + 1.5*inter
  l = q1 - 1.5*inter
  for j in df[i]:
    if j>u or j<l:
      df[i] = df[i].replace(j,q2)

# %%
for j in range(0,len(col)-1):
  clean_out(col[j])

# %% [markdown]
# Implementing Machine Learning Models

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
# hyper parameter tuning
from sklearn.model_selection import GridSearchCV

params = {
    "criterion":("gini", "entropy"),  
    "max_depth":[5,10,15,20], 
    "min_samples_split":[2, 3, 4],"min_samples_split" :[2, 5, 10]
}

# %%
# splitting the data set
x = table.drop(columns = "quality")
y = table.quality

# %%
d_tree = GridSearchCV(DecisionTreeClassifier(),params)

# %% [markdown]
# Decision Tree

# %%
#fitting the model
x1,x2,y1,y2 = train_test_split(x,y,test_size = 0.2, stratify = y,random_state=3)
model = d_tree.fit(x1,y1)
d_pred = d_tree.predict(x2)#predicting for test dataset
ac1 = accuracy_score(y2,d_pred)#checking the accuracy

print(ac1)
# Out:
# 0.7030567685589519

# %%
print("The score of the tree is:",d_tree.score(x2,y2)*100)
# Out:
# The score of the tree is: 70.3056768558952

# %%
#checking best param
print(d_tree.best_params_)
# Out:
# {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 2}

# %%
#importing the tree using tree_plot
from sklearn import tree
plt.figure(figsize=(60,40))
p = tree.plot_tree(DecisionTreeClassifier().fit(x1,y1),rounded= True)

# %%
#creating classification table
d = classification_report(y2,d_pred)
print("Classification table of testing data\n",d)
d1 = classification_report(y1,model.predict(x1))
print("Classification table of training data\n",d1)
# Out:
# Classification table of testing data
#                precision    recall  f1-score   support
#
#            5       0.79      0.77      0.78       105
#            6       0.66      0.63      0.64        92
#            8       0.56      0.69      0.62        32
#
#     accuracy                           0.70       229
#    macro avg       0.67      0.70      0.68       229
# weighted avg       0.71      0.70      0.70       229
#
# Classification table of training data
#                precision    recall  f1-score   support
#
#            5       1.00      1.00      1.00       417
#            6       1.00      1.00      1.00       370
#            8       1.00      1.00      1.00       127
#
#     accuracy                           1.00       914
#    macro avg       1.00      1.00      1.00       914
# weighted avg       1.00      1.00      1.00       914
